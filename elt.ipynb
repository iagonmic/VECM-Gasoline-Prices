# %%
from bcb import sgs
import pandas as pd

ipca = sgs.get(433)
selic1 = sgs.get(432, start='1999-01-15', end='2009-01-14')
selic2 = sgs.get(432, start='2009-01-15', end='2019-01-14')
selic3 = sgs.get(432, start='2019-01-15')
df = pd.concat([selic1,selic2,selic3])
ibc_br = sgs.get(4380)
# Out:
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File c:\Users\Usuario\Desktop\data-science\VECM-Gasoline-Prices\venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\Usuario\Desktop\data-science\VECM-Gasoline-Prices\venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\Usuario\Desktop\data-science\VECM-Gasoline-Prices\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
# ...

# %%
ipca
# Out:
#              433
# Date
# 1980-01-01  6.62
# 1980-02-01  4.62
# 1980-03-01  6.04
# 1980-04-01  5.29
# 1980-05-01  5.70
# ...          ...
# 2025-10-01  0.09
# 2025-11-01  0.18
# 2025-12-01  0.33
# 2026-01-01  0.33
# 2026-02-01  0.70
#
# [554 rows x 1 columns]
